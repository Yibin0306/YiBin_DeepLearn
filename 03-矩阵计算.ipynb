# %% [markdown]
# # 1. 标量导数

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img.png)

# %% [markdown]
# # 2. 亚导数

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_1.png)

# %% [markdown]
# # 3. 求导
# ## 3.1 梯度
#     一、 y是向量，x是标量的话，求导为标量。
#     二、 y是向量，x是向量的话，求导为矩阵。

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_2.png)

# %% [markdown]
# ## 3.2 标量对向量求导
# $x_{1}^{2}+2x_{2}^{2}$是一个椭圆，梯度是指向值变化最大的方向。

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_3.png)

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_4.png)

# %% [markdown]
# ## 3.3 向量对标量求导

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_5.png)

# %% [markdown]
# ## 3.4 向量对向量求导

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_6.png)

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_7.png)

# %% [markdown]
# ## 3.5 扩展矩阵对矩阵求导

# %% [markdown]
# ![](Learn_Pictures/03-矩阵计算/img_8.png)
