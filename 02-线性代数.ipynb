# %% [markdown]
# # 1. 特征值、特征向量求解
#     下图为对矩阵求特征值、求特征向量的相关操作。

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img.png)

# %% [markdown]
# # 2. 标量运算

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_1.png)

# %% [markdown]
# # 3. 向量运算
#     下图中，α是一个标量，
#     是把向量b拉长。

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_2.png)

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_3.png)

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_4.png)

# %% [markdown]
# # 4. 矩阵运算

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_5.png)

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_6.png)

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_7.png)

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_8.png)

# %% [markdown]
#     矩阵长度叫范数，下图为矩阵范数满足的公式。

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_9.png)

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_10.png)

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_11.png)

# %% [markdown]
# # 5. 特征向量、特征值
#     红色、绿色向量都被一个矩阵作用后，红色的大小和方向都被改变了，绿色的仅被改变了大小，没有改变方向。绿色向量为矩阵的特征向量。

# %% [markdown]
# ![](Learn_Pictures/02-线性代数/img_12.png)

# %% [markdown]
# # 6. 线性代数
# ## 6.1 标量
#     标量由只有一个元素的张量表示。
